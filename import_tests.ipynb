# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import xgboost
import pandas as pd
import seaborn as sns
import scipy as sp
import dcor # pip install dcor
import optuna
from itertools import chain, combinations, product
from typing import Callable, Literal
from scipy.ndimage import gaussian_filter

from PIL import Image, ImageOps
from IPython.display import display, HTML # conda install ipython

import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

import torchvision
from torchvision import models, transforms
from torchvision.io import read_image
from torchvision.models import ResNet18_Weights

from skimage.segmentation import mark_boundaries

from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.neural_network import MLPRegressor
from sklearn.utils import shuffle
from sklearn.linear_model import LogisticRegression

from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import ViTImageProcessor, ViTForImageClassification

from lime.lime_tabular import LimeTabularExplainer
from lime import lime_image

import shap
import sage
shap.initjs() # Don't worry if this doesn't work for you. Comment it out and carry on
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.5 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/rasheed/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/rasheed/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/rasheed/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3123, in run_cell
#     result = self._run_cell(
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3178, in _run_cell
#     result = runner(coro)
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3400, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3641, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_52014/518322434.py", line 17, in <module>
#     import torch
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /home/rasheed/dev/xai/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 23
#      20 import torch.optim as optim
#      21 from torch.utils.data import DataLoader, TensorDataset
# ---> 23 import torchvision
#      24 from torchvision import models, transforms
#      25 from torchvision.io import read_image
#
# File ~/dev/xai/.venv/lib/python3.12/site-packages/torchvision/__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File ~/dev/xai/.venv/lib/python3.12/site-packages/torchvision/_meta_registrations.py:163
#     153     torch._check(
#     154         grad.dtype == rois.dtype,
#     155         lambda: (
#    (...)    158         ),
#     159     )
#     160     return grad.new_empty((batch_size, channels, height, width))
# --> 163 @torch._custom_ops.impl_abstract("torchvision::nms")
#     164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#     166     torch._check(dets.size(1) == 4, lambda: f"boxes should have 4 elements in dimension 1, got {dets.size(1)}")
#
# File ~/dev/xai/.venv/lib/python3.12/site-packages/torch/library.py:440, in impl_abstract.<locals>.inner(func)
#     437 else:
#     438     func_to_register = func
# --> 440 handle = entry.abstract_impl.register(func_to_register, source)
#     441 if lib is not None:
#     442     lib._registration_handles.append(handle)
#
# File ~/dev/xai/.venv/lib/python3.12/site-packages/torch/_library/abstract_impl.py:30, in AbstractImplHolder.register(self, func, source)
#      24 if self.kernel is not None:
#      25     raise RuntimeError(
#      26         f"impl_abstract(...): the operator {self.qualname} "
#      27         f"already has an abstract impl registered at "
#      28         f"{self.kernel.source}."
#      29     )
# ---> 30 if torch._C._dispatch_has_kernel_for_dispatch_key(self.qualname, "Meta"):
#      31     raise RuntimeError(
#      32         f"impl_abstract(...): the operator {self.qualname} "
#      33         f"already has an DispatchKey::Meta implementation via a "
#    (...)     36         f"impl_abstract."
#      37     )
#      39 if torch._C._dispatch_has_kernel_for_dispatch_key(
#      40     self.qualname, "CompositeImplicitAutograd"
#      41 ):
#
# RuntimeError: operator torchvision::nms does not exist
